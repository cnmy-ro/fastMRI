# %%
# %matplotlib inline

import sys
sys.path.append("../")


import h5py
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path

# %%
RESULTS_DIR = Path("/exports/lkeb-hpc/csrao/results/fastmri_sc_unet_trial/reconstructions/")
SAMPLE_FILE_NAME = Path("file1000022_v2.h5")

# %%
file_content = h5py.File(RESULTS_DIR / SAMPLE_FILE_NAME)
print('Keys:', list(file_content.keys()))
print('Attrs:', dict(file_content.attrs))
# Out:
# Keys: ['reconstruction']
# Attrs: {}

# %%
recon = file_content['reconstruction']
print(recon.shape)
# Out:
# (37, 1, 320, 320)

# %%
slice = 20
plt.imshow(recon[slice][0], cmap='gray')
